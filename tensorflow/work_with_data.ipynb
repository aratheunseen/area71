# %%
import pandas as pd
import numpy as np

import tensorflow as tf
# Out:
# WARNING:tensorflow:From c:\Users\Mariana\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
abalone_train = pd.read_csv(
    "https://storage.googleapis.com/download.tensorflow.org/data/abalone_train.csv",
    names=["Length", "Diameter", "Height", "Whole weight", "Shucked weight",
           "Viscera weight", "Shell weight", "Age"])

abalone_train.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.435     0.335   0.110         0.334          0.1355          0.0775
# 1   0.585     0.450   0.125         0.874          0.3545          0.2075
# 2   0.655     0.510   0.160         1.092          0.3960          0.2825
# 3   0.545     0.425   0.125         0.768          0.2940          0.1495
# 4   0.545     0.420   0.130         0.879          0.3740          0.1695
#
#    Shell weight  Age
# 0        0.0965    7
# 1        0.2250    6
# 2        0.3700   14
# 3        0.2600   16
# 4        0.2300   13

# %%
abalone_features = abalone_train.copy()
abalone_labels = abalone_features.pop('Age')

abalone_features = np.array(abalone_features)
abalone_features
# Out:
# array([[0.435 , 0.335 , 0.11  , ..., 0.1355, 0.0775, 0.0965],
#        [0.585 , 0.45  , 0.125 , ..., 0.3545, 0.2075, 0.225 ],
#        [0.655 , 0.51  , 0.16  , ..., 0.396 , 0.2825, 0.37  ],
#        ...,
#        [0.53  , 0.42  , 0.13  , ..., 0.3745, 0.167 , 0.249 ],
#        [0.395 , 0.315 , 0.105 , ..., 0.1185, 0.091 , 0.1195],
#        [0.45  , 0.355 , 0.12  , ..., 0.1145, 0.0665, 0.16  ]])

# %% [markdown]
# ---
# ---

# %%
titanic = pd.read_csv("https://storage.googleapis.com/tf-datasets/titanic/train.csv")
titanic_test = pd.read_csv("https://storage.googleapis.com/tf-datasets/titanic/eval.csv")

titanic.head()
titanic_test.head()
# Out:
#    survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0         0    male  35.0                   0      0   8.0500   Third
# 1         0    male  54.0                   0      0  51.8625   First
# 2         1  female  58.0                   0      0  26.5500   First
# 3         1  female  55.0                   0      0  16.0000  Second
# 4         1    male  34.0                   0      0  13.0000  Second
#
#       deck  embark_town alone
# 0  unknown  Southampton     y
# 1        E  Southampton     y
# 2        C  Southampton     y
# 3  unknown  Southampton     y
# 4        D  Southampton     y

# %%
titanic_features = titanic.copy()
titanic_test_features = titanic_test.copy()

titanic_labels = titanic_features.pop('survived')
titanic_test_labels = titanic_test_features.pop('survived')

# %%
# Create a symbolic input
input = tf.keras.Input(shape=(), dtype=tf.float32)

# Perform a calculation using the input
result = 2*input + 1

# the result doesn't have a value
result
# Out:
# <KerasTensor: shape=(None,) dtype=float32 (created by layer 'tf.__operators__.add_1')>

# %%
titanic.head()
# Out:
#    survived     sex   age  n_siblings_spouses  parch     fare  class     deck  \
# 0         0    male  22.0                   1      0   7.2500  Third  unknown
# 1         1  female  38.0                   1      0  71.2833  First        C
# 2         1  female  26.0                   0      0   7.9250  Third  unknown
# 3         1  female  35.0                   1      0  53.1000  First        C
# 4         0    male  28.0                   0      0   8.4583  Third  unknown
#
#    embark_town alone
# 0  Southampton     n
# 1    Cherbourg     n
# 2  Southampton     y
# 3  Southampton     n
# 4   Queenstown     y

# %%
calc = tf.keras.Model(inputs=input, outputs=result)

print(calc(1).numpy())
print(calc(2).numpy())
# Out:
# 3.0
# 5.0
